# %%
import xgboost as xgb
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from extraccion import minioFunctions
import weave
import wandb
# Out:
# c:\Users\Juanan\IgnisAI\c2526-R3\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
from wandb.integration.xgboost import WandbCallback
import xgboost as XGBClassifier

cliente = minioFunctions.crear_cliente()
df = minioFunctions.bajar_fichero(cliente, "grupo3/cleaned/final.parquet", "df")

X = df.drop(["final", "dates"], axis=1)
y = df["final"]


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1)
clf.fit(X_train, y_train)
model_params = clf.get_params()

y_pred = clf.predict(X_test)
y_probas = clf.predict_proba(X_test)
importances = clf.feature_importances_

run = wandb.init(entity="pd1-c2526-team3", project='XGboost', config=model_params)

# visualize all classifier plots
wandb.sklearn.plot_classifier(clf, X_train, X_test, y_train, y_test, y_pred, y_probas, labels = X.columns, model_name="RandomForestClassifier", feature_names=feature_names)

# or visualize individual plots
# plot_class_proportions(y_train, y_test, labels)
# plot_learning_curve(clf, X_train, y_train)
# plot_roc(y_test, y_probas, labels)
# plot_precision_recall(y_test, y_probas, labels)
# plot_feature_importances(clf)

# finish the wandb run
run.finish()
# Out:
# Dataframe importado correctamente
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Juanan\IgnisAI\c2526-R3\.venv\Lib\site-packages\xgboost\data.py:408, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     407 try:
# --> 408     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     409 except KeyError:
#
# KeyError: 'datetime64[us]'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 14
#      11 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#      13 clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1)
# ---> 14 clf.fit(X_train, y_train)
#      15 model_params = clf.get_params()
#      17 y_pred = clf.predict(X_test)
#
# ...
