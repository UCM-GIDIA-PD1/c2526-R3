# %%
from extraccion import minioFunctions as mf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from extraccion import puntos_sinteticos as ps

cliente = mf.crear_cliente()
df = mf.bajar_fichero(cliente, 'grupo3/cleaned/Modelo_Incendios_final.parquet', 'df')
# Out:
# Dataframe importado correctamente

# %%
print(ps.contarSinteticosPorArea(df))
# Out:
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# Geodataframe importado correctamente
# AtlanticRegion: 3901
# BorealRegion: 6410
# MediterraneanRegion: 17381
# BlackSeaRegion: 821
# ContinentalRegion: 10201
# MacaronesianRegion: 18
# PannonianRegion: 991
# SteppicRegion: 3054
# AnatolianRegion: 1475
# ArcticRegion: 1020
# AlpineRegion: 2406
# mascara_Belarus: 762
# mascara_Norte_Africa: 4177
# mascara_Russian_Federation: 7757
# ['AtlanticRegion: 3901', 'BorealRegion: 6410', 'MediterraneanRegion: 17381', 'BlackSeaRegion: 821', 'ContinentalRegion: 10201', 'MacaronesianRegion: 18', 'PannonianRegion: 991', 'SteppicRegion: 3054', 'AnatolianRegion: 1475', 'ArcticRegion: 1020', 'AlpineRegion: 2406', 'mascara_Belarus: 762', 'mascara_Norte_Africa: 4177', 'mascara_Russian_Federation: 7757']

# %%
# Puntos Africa
 
print(ps.crearSinteticosUnaZona(df, 'grupo3/raw/Countries/mascara_Norte_Africa.parquet', 4177))
# Out:
# Geodataframe importado correctamente
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Puntos Africa
# ----> 3 ps.crearSinteticosUnaZona(df, 'grupo3/raw/Countries/mascara_Norte_Africa.parquet', 4177)
#
# File ~\OneDrive\Documents\PROYECTO C++ Y PYTHON\c2526-R3\src\extraccion\puntos_sinteticos.py:489, in crearSinteticosUnaZona(df_incendios, mascara, num_puntos, subir)
#     486 cliente = minioFunctions.crear_cliente()
#     488 # 1.- Obtener DataFrames de incendios por zona
# --> 489 listaZonas = filtros_no_sinteticos.filtrarZona([mascara], df_incendios, cliente)
#     491 zona_df = listaZonas[0]
#     492 frp_total = zona_df['frp_mean'].sum() if len(zona_df) > 0 else 0
#
# ValueError: not enough values to unpack (expected 2, got 1)
