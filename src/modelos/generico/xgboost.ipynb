# %%
import xgboost as xgb
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from extraccion import minioFunctions
import weave
import wandb
import os
# Out:
# c:\Users\Juanan\IgnisAI\c2526-R3\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
from wandb.integration.xgboost import WandbCallback
from wandb.sklearn import plot_class_proportions, plot_learning_curve, plot_roc, plot_precision_recall, plot_feature_importances
import xgboost as XGBClassifier

cliente = minioFunctions.crear_cliente()
df = minioFunctions.bajar_fichero(cliente, "grupo3/cleaned/final.parquet", "df")

minioFunctions.load_dotenv()
os.environ['WANDB_API_KEY'] = os.getenv('WANDB_KEY')

X = df.drop(["final", "date"], axis=1)
y = df["final"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

clf = xgb.XGBClassifier(n_estimators=10000, learning_rate=0.1)
clf.fit(X_train, y_train, )
model_params = clf.get_params()

y_pred = clf.predict(X_test)
y_probas = clf.predict_proba(X_test)
importances = clf.feature_importances_

run = wandb.init(entity="pd1-c2526-team3", name = "XGBoost Experimento 2 (más iteraciones)", project='XGboost', config=model_params)

wandb.sklearn.plot_classifier(clf, X_train, X_test, y_train, y_test, y_pred, y_probas, labels = X.columns, model_name="XGBoostClassifier", feature_names=X.columns)

plot_class_proportions(y_train, y_test, X.columns)
plot_learning_curve(clf, X_train, y_train)
plot_roc(y_test, y_probas, X.columns)
plot_precision_recall(y_test, y_probas, X.columns)
plot_feature_importances(clf)

run.finish()
# Out:
# Dataframe importado correctamente
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>c:\Users\Juanan\IgnisAI\c2526-R3\src\modelos\generico\wandb\run-20260311_162444-8mu4idcz</code>
# Syncing run <strong><a href='https://wandb.ai/pd1-c2526-team3/XGboost/runs/8mu4idcz' target="_blank">XGBoost Experimento 2 (más iteraciones)</a></strong> to <a href='https://wandb.ai/pd1-c2526-team3/XGboost' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/pd1-c2526-team3/XGboost' target="_blank">https://wandb.ai/pd1-c2526-team3/XGboost</a>
#  View run at <a href='https://wandb.ai/pd1-c2526-team3/XGboost/runs/8mu4idcz' target="_blank">https://wandb.ai/pd1-c2526-team3/XGboost/runs/8mu4idcz</a>
# wandb: Initializing weave.
# weave: wandb version 0.25.1 is available!  To upgrade, please run:
# weave:  $ pip install wandb --upgrade
# ...
